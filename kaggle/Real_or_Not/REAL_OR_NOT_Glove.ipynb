# %% [markdown]
# ## What files do I need?
# You'll need train.csv, test.csv and sample_submission.csv.
#
# ## What should I expect the data format to be?
# - Each sample in the train and test set has the following information:
# - The text of a tweet
# - A keyword from that tweet (although this may be blank!)
# - The location the tweet was sent from (may also be blank)
#
# ## What am I predicting?
# You are predicting whether a given tweet is about a real disaster or not. If so, predict a 1. If not, predict a 0.
#
# ## Files
# - train.csv - the training set
# - test.csv - the test set
# - sample_submission.csv - a sample submission file in the correct format
#
# ## Columns
# - id - a unique identifier for each tweet
# - text - the text of the tweet
# - location - the location the tweet was sent from (may be blank)
# - keyword - a particular keyword from the tweet (may be blank)
# - target - in train.csv only, this denotes whether a tweet is about a real disaster (1) or not (0)

# %% [markdown]
# # importing library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from nltk.tokenize import WordPunctTokenizer 
import string
from tqdm import tqdm
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
stop=set(stopwords.words('english'))
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Embedding,LSTM,Dense,SpatialDropout1D
from keras.initializers import Constant
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # reading dataset

# %%
df_train = pd.read_csv(r'C:\Users\MOMOZZING\WorkSpace\kaggle\Real_or_Not\train.csv', dtype={'id': np.int16, 'target': np.int8})
df_test = pd.read_csv(r'C:\Users\MOMOZZING\WorkSpace\kaggle\Real_or_Not\test.csv', dtype={'id': np.int16})
df_sub = pd.read_csv(r'C:\Users\MOMOZZING\WorkSpace\kaggle\Real_or_Not\sample_submission.csv', dtype={'id': np.int16})

# %% [markdown]
# # data exploring&cleaning

# %%
df_train
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
# id          7613 non-null int16
# keyword     7552 non-null object
# location    5080 non-null object
# text        7613 non-null object
# target      7613 non-null int8
# dtypes: int16(1), int8(1), object(3)
# memory usage: 200.9+ KB

# %%
df_train.shape
# Out:
# (7613, 5)

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3263 entries, 0 to 3262
# Data columns (total 4 columns):
# id          3263 non-null int16
# keyword     3237 non-null object
# location    2158 non-null object
# text        3263 non-null object
# dtypes: int16(1), object(3)
# memory usage: 83.0+ KB

# %%
df_test.shape
# Out:
# (3263, 4)

# %%
target_df_train = df_train.groupby('target').target.count()

# %%
target_df_train
# Out:
# target
# 0    4342
# 1    3271
# Name: target, dtype: int64

# %%
label = ['disaster', 'non_disaster']

# %%
plt.bar(label[1],target_df_train[0], color = 'r')
plt.bar(label[0],target_df_train[1], color = 'b')
plt.show()

# %% [markdown]
# 이 예제 를 풀려면 텍스트에 대한 분류와 binary classification이 필요할 것 같다. 이 부분에서 공부를 해야할 것 같다.
# 텍스트를 통한 KEYWORD분류도 가능할 것 같다.

# %% [markdown]
# # URL 제거

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'',text)

# %%
all_df=pd.concat([df_train,df_test])
all_df.shape
# Out:
# C:\Users\MOMOZZING\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# (10876, 5)

# %%
all_df['text']=all_df['text'].apply(lambda x : remove_URL(x))

# %% [markdown]
# # HTML 태그 제거

# %%
def remove_html(text):
    html=re.compile(r'<.*?>')
    return html.sub(r'',text)

# %%
all_df['text']=all_df['text'].apply(lambda x : remove_html(x))

# %% [markdown]
# # 구둣점 제거

# %%
def remove_punct(text):
    table=str.maketrans('','',string.punctuation)
    return text.translate(table)

# %%
all_df['text']=all_df['text'].apply(lambda x : remove_punct(x))

# %% [markdown]
# # 토큰화

# %%
print(all_df['text'])
print(type(all_df['text']))
text = all_df['text']
# Out:
# 0       Our Deeds are the Reason of this earthquake Ma...
# 1                   Forest fire near La Ronge Sask Canada
# 2       All residents asked to shelter in place are be...
# 3       13000 people receive wildfires evacuation orde...
# 4       Just got sent this photo from Ruby Alaska as s...
#                               ...
# 3258    EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259    Storm in RI worse than last hurricane My citya...
# 3260                    Green Line derailment in Chicago
# 3261            MEG issues Hazardous Weather Outlook HWO
# 3262    CityofCalgary has activated its Municipal Emer...
# Name: text, Length: 10876, dtype: object
# <class 'pandas.core.series.Series'>

# %%
tokenizer = WordPunctTokenizer() 

text = all_df['text']

text_list = text.tolist()

temp_list = []
for text in text_list:
    temp_list.append(tokenizer.tokenize(text))

print(temp_list)
# Out:
# [['Our', 'Deeds', 'are', 'the', 'Reason', 'of', 'this', 'earthquake', 'May', 'ALLAH', 'Forgive', 'us', 'all'], ['Forest', 'fire', 'near', 'La', 'Ronge', 'Sask', 'Canada'], ['All', 'residents', 'asked', 'to', 'shelter', 'in', 'place', 'are', 'being', 'notified', 'by', 'officers', 'No', 'other', 'evacuation', 'or', 'shelter', 'in', 'place', 'orders', 'are', 'expected'], ['13000', 'people', 'receive', 'wildfires', 'evacuation', 'orders', 'in', 'California'], ['Just', 'got', 'sent', 'this', 'photo', 'from', 'Ruby', 'Alaska', 'as', 'smoke', 'from', 'wildfires', 'pours', 'into', 'a', 'school'], ['RockyFire', 'Update', 'California', 'Hwy', '20', 'closed', 'in', 'both', 'directions', 'due', 'to', 'Lake', 'County', 'fire', 'CAfire', 'wildfires'], ['flood', 'disaster', 'Heavy', 'rain', 'causes', 'flash', 'flooding', 'of', 'streets', 'in', 'Manitou', 'Colorado', 'Springs', 'areas'], ['Im', 'on', 'top', 'of', 'the', 'hill', 'and', 'I', 'can', 'see', 'a', 'fire', 'in', 'the', 'woods'], ['Theres', 'an', 'emergency', 'evacuation', 'happening', 'now', 'in', 'the', 'building', 'across', 'the', 'street'], ['Im', 'afraid', 'that', 'the', 'tornado', 'is', 'coming', 'to', 'our', 'area'], ['Three', 'people', 'died', 'from', 'the', 'heat', 'wave', 'so', 'far'], ['Haha', 'South', 'Tampa', 'is', 'getting', 'flooded', 'hah', 'WAIT', 'A', 'SECOND', 'I', 'LIVE', 'IN', 'SOUTH', 'TAMPA', 'WHAT', 'AM', 'I', 'GONNA', 'DO', 'WHAT', 'AM', 'I', 'GONNA', 'DO', 'FVCK', 'flooding'], ['raining', 'flooding', 'Florida', 'TampaBay', 'Tampa', '18', 'or', '19', 'days', 'Ive', 'lost', 'count'], ['Flood', 'in', 'Bago', 'Myanmar', 'We', 'arrived', 'Bago'], ['Damage', 'to', 'school', 'bus', 'on', '80', 'in', 'multi', 'car', 'crash', 'BREAKING'], ['Whats', 'up', 'man'], ['I', 'love', 'fruits'], ['Summer', 'is', 'lovely'], ['My', 'car', 'is', 'so', 'fast'], ['What', 'a', 'goooooooaaaaaal'], ['this', 'is', 'ridiculous'], ['London', 'is', 'cool'], ['Love', 'skiing'], ['What', 'a', 'wonderful', 'day'], ['LOOOOOOL'], ['No', 'wayI', 'cant', 'eat', 'that', 'shit'], ['Was', 'in', 'NYC', 'last', 'week'], ['Love', 'my', 'girlfriend'], ['Cooool'], ['Do', 'you', 'like', 'pasta'], ['The', 'end'], ['bbcmtd', 'Wholesale', 'Markets', 'ablaze'], ['We', 'always', 'try', 'to', 'bring', 'the', 'heavy', 'metal', 'RT'], ['AFRICANBAZE', 'Breaking', 'newsNigeria', 'flag', 'set', 'ablaze', 'in', 'Aba'], ['Crying', 'out', 'for', 'more', 'Set', 'me', 'ablaze'], ['On', 'plus', 'side', 'LOOK', 'AT', 'THE', 'SKY', 'LAST', 'NIGHT', 'IT', 'WAS', 'ABLAZE'], ['PhDSquares', 'mufc', 'theyve', 'built', 'so', 'much', 'hype', 'around', 'new', 'acquisitions', 'but', 'I', 'doubt', 'they', 'will', 'set', 'the', 'EPL', 'ablaze', 'this', 'season'], ['INEC', 'Office', 'in', 'Abia', 'Set', 'Ablaze'], ['Barbados', 'Bridgetown', 'JAMAICA', '\x89', 'ÛÒ', 'Two', 'cars', 'set', 'ablaze', 'SANTA', 'CRUZ', '\x89', 'ÛÓ', 'Head', 'of', 'the', 'St', 'Elizabeth', 'Police', 'Superintende'], ['Ablaze', 'for', 'you', 'Lord', 'D'], ['Check', 'these', 'out', 'nsfw'], ['on', 'the', 'outside', 'youre', 'ablaze', 'and', 'alive', 'but', 'youre', 'dead', 'inside'], ['Had', 'an', 'awesome', 'time', 'visiting', 'the', 'CFC', 'head', 'office', 'the', 'ancop', 'site', 'and', 'ablaze', 'Thanks', 'to', 'Tita', 'Vida', 'for', 'taking', 'care', 'of', 'us'], ['SOOOO', 'PUMPED', 'FOR', 'ABLAZE', 'southridgelife'], ['I', 'wanted', 'to', 'set', 'Chicago', 'ablaze', 'with', 'my', 'preaching', 'But', 'not', 'my', 'hotel'], ['I', 'gained', '3', 'followers', 'in', 'the', 'last', 'week', 'You', 'Know', 'your', 'stats', 'and', 'grow', 'with'], ['How', 'the', 'West', 'was', 'burned', 'Thousands', 'of', 'wildfires', 'ablaze', 'in', 'California', 'alone'], ['Building', 'the', 'perfect', 'tracklist', 'to', 'life', 'leave', 'the', 'streets', 'ablaze'], ['Check', 'these', 'out', 'nsfw'], ['First', 'night', 'with', 'retainers', 'in', 'Its', 'quite', 'weird', 'Better', 'get', 'used', 'to', 'it', 'I', 'have', 'to', 'wear', 'them', 'every', 'single', 'night', 'for', ' ...

# %% [markdown]
# # glove

# %%
def create_corpus(all_df):
    corpus=[]
    for df_train in tqdm(all_df['text']):
        words=[word.lower() for word in word_tokenize(df_train) if((word.isalpha()==1) & (word not in stop))]
        corpus.append(words)
    return corpus

# %%
corpus=create_corpus(all_df)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 10876/10876 [00:01<00:00, 10069.32it/s]

# %%
corpus
# Out:
# [['our', 'deeds', 'reason', 'earthquake', 'may', 'allah', 'forgive', 'us'],
#  ['forest', 'fire', 'near', 'la', 'ronge', 'sask', 'canada'],
#  ['all',
#   'residents',
#   'asked',
#   'shelter',
#   'place',
#   'notified',
#   'officers',
#   'no',
#   'evacuation',
#   'shelter',
#   'place',
#   'orders',
#   'expected'],
#  ['people', 'receive', 'wildfires', 'evacuation', 'orders', 'california'],
#  ['just',
#   'got',
#   'sent',
#   'photo',
#   'ruby',
#   'alaska',
#   'smoke',
#   'wildfires',
#   'pours',
#   'school'],
#  ['rockyfire',
#   'update',
#   'california',
#   'hwy',
#   'closed',
#   'directions',
#   'due',
#   'lake',
#   'county',
#   'fire',
#   'cafire',
#   'wildfires'],
#  ['flood',
#   'disaster',
#   'heavy',
#   'rain',
#   'causes',
#   'flash',
#   'flooding',
#   'streets',
#   'manitou',
#   'colorado',
#   'springs',
#   'areas'],
#  ['im', 'top', 'hill', 'i', 'see', 'fire', 'woods'],
#  ['theres',
#   'emergency',
#   'evacuation',
#   'happening',
#   'building',
#   'across',
#   'street'],
#  ['im', 'afraid', 'tornado', 'coming', 'area'],
#  ['three', 'people', 'died', 'heat', 'wave', 'far'],
#  ['haha',
#   'south',
#   'tampa',
#   'getting',
#   'flooded',
#   'hah',
#   'wait',
#   'a',
#   'second',
#   'i',
#   'live',
#   'in',
#   'south',
#   'tampa',
#   'what',
#   'am',
#   'i',
#   'gon',
#   'na',
#   'do',
#   'what',
#   'am',
#   'i',
#   'gon',
#   'na',
#   'do',
#   'fvck',
#   'flooding'],
#  ['raining',
#   'flooding',
#   'florida',
#   'tampabay',
#   'tampa',
#   'days',
#   'ive',
#   'lost',
#   'count'],
#  ['flood', 'bago', 'myanmar', 'we', 'arrived', 'bago'],
#  ['damage', 'school', 'bus', 'multi', 'car', 'crash', 'breaking'],
#  ['whats', 'man'],
#  ['i', 'love', 'fruits'],
#  ['summer', 'lovely'],
#  ['my', 'car', 'fast'],
#  ['what', 'goooooooaaaaaal'],
#  ['ridiculous'],
#  ['london', 'cool'],
#  ['love', 'skiing'],
#  ['what', 'wonderful', 'day'],
#  ['looooool'],
#  ['no', 'wayi', 'cant', 'eat', 'shit'],
#  ['was', 'nyc', 'last', 'week'],
#  ['love', 'girlfriend'],
#  ['cooool'],
#  ['do', 'like', 'pasta'],
#  ['the', 'end'],
#  ['bbcmtd', 'wholesale', 'markets', 'ablaze'],
#  ['we', 'always', 'try', 'bring', 'heavy', 'metal', 'rt'],
#  ['africanbaze', 'breaking', 'newsnigeria', 'flag', 'set', 'ablaze', 'aba'],
#  ['crying', 'set', 'ablaze'],
#  ['on',
#   'plus',
#   'side',
#   'look',
#   'at',
#   'the',
#   'sky',
#   'last',
#   'night',
#   'it',
#   'was',
#   'ablaze'],
#  ['phdsquares',
#   'mufc',
#   'theyve',
#   'built',
#   'much',
#   'hype',
#   'around',
#   'new',
#   'acquisitions',
#   'i',
#   'doubt',
#   'set',
#   'epl',
#   'ablaze',
#   'season'],
#  ['inec', 'office', 'abia', 'set', 'ablaze'],
#  ['barbados',
#   'bridgetown',
#   'jamaica',
#   'two',
#   'cars',
#   'set',
#   'ablaze',
#   'santa',
#   'cruz',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintende'],
#  ['ablaze', 'lord', 'd'],
#  ['check', 'nsfw'],
#  ['outside', 'youre', 'ablaze', 'alive', 'youre', 'dead', 'inside'],
#  ['had',
#   'awesome',
#   'time',
#   'visiting',
#   'cfc',
#   'head',
#   'office',
#   'ancop',
#   'site',
#   'ablaze',
#   'thanks',
#   'tita',
#   'vida',
#   'taking',
#   'care',
#   'us'],
#  ['soooo', 'pumped', 'for', 'ablaze', 'southridgelife'],
#  ['i', 'wanted', 'set', 'chicago', 'ablaze', 'preaching', 'but', 'hotel'],
#  ['i', 'gained', 'followers', 'last', 'week', 'you', 'know', 'stats', 'grow'],
#  ['how',
#   'west',
#   'burned',
#   'thousands',
#   'wildfires',
#   'ablaze',
#   'california',
#   'alone'],
#  ['building', 'perfect', 'tracklist', 'life', 'leave', 'streets', 'ablaze'],
#  ['check', 'nsfw'],
#  ['first',
#   'night',
#   'retainers',
#   'its',
#   'quite',
#   'weird',
#   'better',
#   'get',
#   'used',
#   'i',
#   'wear',
#   'every',
#   'single',
#   'night',
#   'next',
#   'year',
#   'least'],
#  ['deputies', 'man', 'shot', 'brighton', 'home', 'set', 'ablaze'],
#  ['man', 'wife', 'get', 'six', 'years', 'jail', 'setting', 'ablaze', 'niece'],
#  ['santa',
#   'cruz',
#   'head',
#   'st',
#   'elizabeth',
#   'police',
#   'superintendent',
#   'lanford',
#   'salmon',
#   'r'],
#  ['police',
#   'arsonist',
#   'deliberately',
#   'set',
#   'black',
#   'church',
#   'in',
#   'north',
#   'carolinaåêablaze'],
#  ['noches',
#   'elbestia',
#   'alexissanchez',
#   'happy',
#   'see',
#   'teammates',
#   'training',
#   'hard',
#   'goodnight',
#   'gunners'],
#  ['kurds',
#   'trampling',
#   'turkmen',
#   'flag',
#   'later',
#   'set',
#   'ablaze',
#   'others',
#   'vandalized',
#   'offices',
#   'turkmen',
#   'front',
#   'diyala'],
#  ['truck',
#   'ablaze',
#   'voortrekker',
#   'ave',
#   'outside',
#   'or',
#   'tambo',
#   'intl',
#   'cargo',
#   'section'],
#  ['set',
#   'hearts',
#   'ablaze',
#   'every',
#   'city',
#   'gift',
#   'and',
#   'every',
#   'skyline',
#   'like',
#   'kiss',
#   'upon',
#   'lips'],
#  ['they',
#   'sky',
#   'ablaze',
#   'tonight',
#   'los',
#   'angeles',
#   'im',
#   'expecting',
#   'ig',
#   'fb',
#   'filled',
#   'sunset',
#   'shots',
#   'i',
#   'know',
#   'peeps'],
#  ['how',
#   'west',
#   'burned',
#   'thousands',
#   'wildfires',
#   'ablaze',
#   'california',
#   'alone',
#   'climate',
#   'energy'],
#  ['revel',
#   'wmv',
#   'videos',
#   'means',
#   'mac',
#   'farewell',
#   'ablaze',
#   'wmv',
#   'en',
#   'route',
#   'dvd',
#   'gtxrwm'],
#  ['progressive',
#   'greetings',
#   'in',
#   'month',
#   'students',
#   'would',
#   'set',
#   'pens',
#   'ablaze',
#   'the',
#   'torch',
#   'publications'],
#  ['rene',
#   'ablaze',
#   'amp',
#   'jacinta',
#   'secret',
#   'fallen',
#   'skies',
#   'edit',
#   'mar'],
#  ['steve',
#   'fires',
#   'something',
#   'else',
#   'california',
#   'tinderbox',
#   'clown',
#   'setting',
#   'hood',
#   'ablaze'],
#  ['nowplaying', 'rene', 'ablaze', 'amp', 'ian', 'buff', 'magnitude', 'edm'],
#  ['nxwestmidlands', 'huge', 'fire', 'wholesale', 'markets', 'ablaze'],
#  ['ablaze',
#   'time',
#   'talk',
#   'go',
#   'i',
#   'dont',
#   'know',
#   'i',
#   'make',
#   'due',
#   'work'],
#  ['i',
#   'cant',
#   'kids',
#   'cuz',
#   'i',
#   'got',
#   'bicycle',
#   'accident',
#   'amp',
#   'split',
#   'testicles',
#   'impossible',
#   'kids',
#   'michael',
#   'you',
#   'are',
#   'the',
#   'father'],
#  ['accident', 'w', 'nashvilletraffic', 'traffic', 'moving', 'slower', 'usual'],
#  ['accident',
#   'center',
#   'lane',
#   'blocked',
#   'santaclara',
#   'nb',
#   'great',
#   'america',
#   'pkwy',
#   'bayarea',
#   'traffic'],
#  ['had',
#   'personalinjury',
#   'accident',
#   'summer',
#   'read',
#   'advice',
#   'amp',
#   'see',
#   'solicitor',
#   'help',
#   'otleyhour'],
#  ['stlouis',
#   'caraccidentlawyer',
#   'speeding',
#   'among',
#   'top',
#   'causes',
#   'teen',
#   'accidents',
#   'car',
#   'accident'],
#  ['reported',
#   'motor',
#   'vehicle',
#   'accident',
#   'curry',
#   'herman',
#   'rd',
#   'near',
#   'stephenson',
#   'involving',
#   'overturned',
#   'vehicle',
#   'please',
#   'use'],
#  ['bigrigradio', 'live', 'accident', 'awareness'],
#  ['mile',
#   'marker',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'ramp',
#   'closed',
#   'pm'],
#  ['rt',
#   'sleepjunkies',
#   'sleeping',
#   'pills',
#   'double',
#   'risk',
#   'car',
#   'accident'],
#  ['by', 'accident', 'knew', 'gon', 'happen'],
#  ['traffic', 'accident', 'n', 'cabrillo', 'hwymagellan', 'av', 'mir'],
#  ['mile',
#   'marker',
#   'south',
#   'mooresville',
#   'iredell',
#   'vehicle',
#   'accident',
#   'congestion',
#   'pm'],
#  ['pastor', 'scene', 'accidentwho', 'owner', 'range', 'rover'],
#  ['mom',
#   'didnt',
#   'get',
#   'home',
#   'fast',
#   'wished',
#   'mom',
#   'accident',
#   'truck',
#   'spilt',
#   'mayonnaise'],
#  ['i',
#   'horrible',
#   'car',
#   'accident',
#   'past',
#   'sunday',
#   'im',
#   'finally',
#   'able',
#   'get',
#   'around',
#   'thank',
#   'god'],
#  ['can',
#   'wait',
#   'see',
#   'pissed',
#   'donnie',
#   'i',
#   'tell',
#   'i',
#   'another',
#   'accident'],
#  ['truckcrash',
#   'overturns',
#   'on',
#   'fortworth',
#   'interstate',
#   'click',
#   'youve',
#   'crashgt'],
#  ['accident', 'ashville', 'us', 'sb', 'sr', 'traffic'],
#  ['carolina',
#   'accident',
#   'motorcyclist',
#   'dies',
#   'crash',
#   'with',
#   'car',
#   'that',
#   'crossed',
#   'median',
#   'a',
#   'motorcycle',
#   'rider',
#   'traveling'],
#  ['fyi', 'cadfyi', 'accident', 'property', 'piner', 'rdhorndale', 'dr'],
#  ['rt',
#   'naayf',
#   'first',
#   'accident',
#   'years',
#   'turning',
#   'onto',
#   'chandanee',
#   'magu',
#   'near',
#   'mma',
#   'taxi',
#   'rammed',
#   'i',
#   'halfway',
#   'turned',
#   'everyone'],
#  ['accident',
#   'left',
#   'lane',
#   'blocked',
#   'manchester',
#   'rt',
#   'nb',
#   'eddy',
#   'rd',
#   'stop',
#   'go',
#   'traffic',
#   'back',
#   'delay',
#   'mins',
#   'traffic'],
#  ['accident', 'property', 'damage', 'piner', 'rdhorndale', 'dr'],
#  ['accident'],
#  ['fyi', 'cadfyi', 'accident', 'property', 's', 'st'],
#  ['pm', 'traffic', 'accident', 'no', 'injury', 'willis', 'foreman', 'rd'],
#  ['aashiqui',
#   'actress',
#   'anu',
#   'aggarwal',
#   'on',
#   'her',
#   'nearfatal',
#   'accident'],
#  ['suffield', 'alberta', 'accident'],
#  ['mile',
#   'backup',
#   'southaccident',
#   'blocking',
#   'right',
#   'lanes',
#   'exit',
#   'langtree',
#   'rdconsider',
#   'nc',
#   'nc',
#   'nc',
#   'alternate'],
#  ['has',
#   'accident',
#   'changed',
#   'life',
#   'we',
#   'help',
#   'determine',
#   'options',
#   'financially',
#   'support',
#   'life',
#   'care',
#   'plans',
#   'ongoing',
#   'treatment'],
#  ['breaking',
#   'deadly',
#   'motorcycle',
#   'car',
#   'accident',
#   'happened',
#   'hagerstown',
#   'today',
#   'ill',
#   'details',
#   'whag'],
#  ['flowri', 'marinading', 'accident'],
#  ['car',
#   'even',
#   'week',
#   'got',
#   'fucking',
#   'car',
#   'accident',
#   'mfs',
#   'cant',
#   'fucking',
#   'drive'],
#  ['norwaymfa',
#   'bahrain',
#   'police',
#   'previously',
#   'died',
#   'road',
#   'accident',
#   'killed',
#   'explosion'],
#  ['i',
#   'still',
#   'heard',
#   'church',
#   'leaders',
#   'kenya',
#   'coming',
#   'forward',
#   'comment',
#   'accident',
#   'issue',
#   'disciplinary',
#   'measuresarrestpastornganga'],
#  ['aftershockdelo', 'scuf', 'ps', 'live', 'game', 'cya'],
#  ['the',
#   'man',
#   'drive',
#   'effort',
#   'gets',
#   'painful',
#   'man',
#   'win',
#   'roger',
#   'bannister'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['there',
#   'victory',
#   'bargain',
#   'basement',
#   'prices',
#   'dwight',
#   'david',
#   'eisenhower'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['nobody', 'remembers', 'came', 'second', 'charles', 'schulz'],
#  ['aftershockdelo',
#   'im',
#   'speaking',
#   'someone',
#   'using',
#   'scuf',
#   'people',
#   'end',
#   'getting',
#   'ps',
#   'also'],
#  ['the', 'harder', 'conflict', 'glorious', 'triumph', 'thomas', 'paine'],
#  ['growingupspoiled',
#   'going',
#   'clay',
#   'pigeon',
#   'shooting',
#   'crying',
#   'aftershock'],
#  ['so', 'guess', 'one', 'actually', 'wants', 'free', 'aftershock', 'tc'],
#  ['aftershock',
#   'terrifying',
#   'best',
#   'roller',
#   'coaster',
#   'ive',
#   'ever',
#   'disclaimer',
#   'ive'],
#  ['aftershock'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['kjfordays', 'im', 'seeing', 'issues', 'aftershock'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['ir',
#   'icemoon',
#   'aftershock',
#   'djicemoon',
#   'dubstep',
#   'trapmusic',
#   'dnb',
#   'edm',
#   'dance'],
#  ['wisdomwed',
#   'bonus',
#   'minute',
#   'daily',
#   'habits',
#   'could',
#   'really',
#   'improve',
#   'life',
#   'how',
#   'many',
#   'already',
#   'lifehacks'],
#  ['aftershock',
#   'protect',
#   'yourself',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   'meltdown',
#   'david',
#   'wiedemer',
#   'http'],
#  ['that',
#   'moment',
#   'get',
#   'scary',
#   'roller',
#   'coaster',
#   'guy',
#   'behind',
#   'screaming',
#   'bloody',
#   'murder',
#   'silverwood',
#   'aftershock'],
#  ['aftershock', 'streaming', 'youtube'],
#  ['gtgt',
#   'aftershock',
#   'protect',
#   'yourself',
#   'profit',
#   'next',
#   'global',
#   'financial',
#   'book',
#   'esquireattire'],
#  ['sometimes',
#   'face',
#   'difficulties',
#   'youre',
#   'something',
#   'wrong',
#   'youre',
#   'something',
#   'right',
#   'joel',
#   'osteen'],
#  ['the',
#   'thing',
#   'stands',
#   'dream',
#   'try',
#   'belief',
#   'actually',
#   'possible',
#   'joel',
#   'brown'],
#  ['praise', 'god', 'ministry', 'tells', 'like', 'wdyouth', 'biblestudy'],
#  ['remembering',
#   'going',
#   'die',
#   'best',
#   'way',
#   'i',
#   'know',
#   'avoid',
#   'trap',
#   'thinking',
#   'something',
#   'lose',
#   'steve',
#   'jobs'],
#  ['tried', 'orange', 'aftershock', 'today', 'my', 'life', 'never'],
#  ['onfireanders', 'i', 'love', 'bb'],
#  ['aftershock'],
#  ['aftershock',
#   'back',
#   'school',
#   'kick',
#   'great',
#   'i',
#   'want',
#   'thank',
#   'everyone',
#   'making',
#   'possible',
#   'what',
#   'great',
#   'night'],
#  ['people', 'say', 'done', 'interrupt', 'george', 'bernard', 'shaw'],
#  ['the',
#   'first',
#   'man',
#   'gets',
#   'oyster',
#   'second',
#   'man',
#   'gets',
#   'shell',
#   'andrew',
#   'carnegie'],
#  ['anyone',
#   'need',
#   'pu',
#   'tonight',
#   'i',
#   'play',
#   'hybrid',
#   'slayer',
#   'eu',
#   'hmu',
#   'empirikgaming',
#   'codawscrims',
#   'aftershockorg'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'news'],
#  ['strict',
#   'liability',
#   'context',
#   'airplane',
#   'accident',
#   'pilot',
#   'error',
#   'common',
#   'component',
#   'aviation',
#   'cr'],
#  ['crobscarla', 'lifetime', 'odds', 'dying', 'airplane', 'accident'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn'],
#  ['alexalltimelow',
#   'awwww',
#   'theyre',
#   'airplane',
#   'accident',
#   'theyre',
#   'gon',
#   'na',
#   'die',
#   'cuties',
#   'good',
#   'job'],
#  ['family',
#   'members',
#   'osama',
#   'bin',
#   'laden',
#   'died',
#   'airplane',
#   'accident',
#   'ironic',
#   'mhmmm',
#   'gov',
#   'shit',
#   'suspect'],
#  ['man', 'goes', 'airplane', 'engine', 'accident', 'via', 'youtube'],
#  ['horrible', 'accident', 'man', 'died', 'in', 'wings', 'airplane'],
#  ['a',
#   'cessna',
#   'airplane',
#   'accident',
#   'ocampo',
#   'coahuila',
#   'mexico',
#   'july',
#   'killed',
#   'four',
#   'men',
#   'including',
#   'state',
#   'coahuila',
#   'government',
#   'official'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'in',
#   'wings',
#   'airplane',
#   'watchthevideo'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining'],
#  ['kca',
#   'mbataweel',
#   'rip',
#   'binladen',
#   'family',
#   'members',
#   'killed',
#   'airplanes',
#   'accident'],
#  ['i',
#   'almost',
#   'sent',
#   'coworker',
#   'nudes',
#   'accident',
#   'thank',
#   'god',
#   'airplane',
#   'mode'],
#  ['mickinyman',
#   'theatlantic',
#   'that',
#   'might',
#   'killed',
#   'airplane',
#   'accident',
#   'night',
#   'car',
#   'wreck',
#   'politics',
#   'best'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'mlb'],
#  ['this',
#   'unbelievably',
#   'insane',
#   'man',
#   'airport',
#   'airplane',
#   'aircraft',
#   'aeroplane',
#   'runway',
#   'accident'],
#  ['horrible', 'accident', 'man', 'died', 'in', 'wings'],
#  ['horrible', 'accident', 'man', 'died', 'in', 'wings', 'airplane'],
#  ['usama',
#   'bin',
#   'ladins',
#   'family',
#   'dead',
#   'airplane',
#   'crash',
#   'naturally',
#   'accident'],
#  ['pilot',
#   'dies',
#   'in',
#   'plane',
#   'crash',
#   'at',
#   'car',
#   'festival',
#   'via',
#   'youtube',
#   'crash',
#   'aircraft',
#   'airplane',
#   'pilot',
#   'death',
#   'accident',
#   'carfest'],
#  ['strict', 'liability', 'context', 'airplane', 'accident'],
#  ['dtn',
#   'brazil',
#   'experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'exp'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wedn'],
#  ['horrible',
#   'accident',
#   'man',
#   'died',
#   'in',
#   'wings',
#   'of',
#   'wtf',
#   'you',
#   'believe',
#   'your',
#   'eyes'],
#  ['nicole',
#   'fletcher',
#   'one',
#   'victim',
#   'crashed',
#   'airplane',
#   'times',
#   'ago',
#   'the',
#   'accident',
#   'left',
#   'little',
#   'bit',
#   'trauma',
#   'although',
#   'shes'],
#  ['omg', 'horrible', 'accident', 'man', 'died', 'wings', 'airplane'],
#  ['omg',
#   'i',
#   'dont',
#   'believe',
#   'rip',
#   'bro',
#   'airplane',
#   'accident',
#   'jetengine',
#   'turbojet',
#   'boing'],
#  ['experts',
#   'france',
#   'begin',
#   'examining',
#   'airplane',
#   'debris',
#   'found',
#   'reunion',
#   'island',
#   'french',
#   'air',
#   'accident',
#   'experts',
#   'wednesday',
#   'began',
#   'examining'],
#  ['i', 'airplane', 'accident'],
#  ['my',
#   'phone',
#   'looks',
#   'like',
#   'car',
#   'ship',
#   'airplane',
#   'accident',
#   'terrible'],
#  ['statistically',
#   'im',
#   'risk',
#   'getting',
#   'killed',
#   'cop',
#   'i',
#   'dying',
#   'airplane',
#   'accident'],
#  ['airplane', 'crashes', 'house', 'colombia', 'people', 'die', 'accident'],
#  ['the', 'shooting', 'airplane', 'accident'],
#  ['could',
#   'drone',
#   'cause',
#   'airplane',
#   'accident',
#   'pilots',
#   'worried',
#   'use',
#   'drones',
#   'esp',
#   'close',
#   'vicinity',
#   'airports'],
#  ['early',
#   'wake',
#   'call',
#   'sister',
#   'begging',
#   'come',
#   'amp',
#   'ride',
#   'wher',
#   'ambulance',
#   'hospital',
#   'rodkiai'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['two',
#   'air',
#   'ambulances',
#   'scene',
#   'serious',
#   'crash',
#   'two',
#   'cars',
#   'lorry'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'reuters',
#   'yugvani'],
#  ['leading',
#   'emergency',
#   'services',
#   'boss',
#   'welcomes',
#   'new',
#   'ambulance',
#   'charity'],
#  ['anyone',
#   'travelling',
#   'aberystwythshrewsbury',
#   'right',
#   'theres',
#   'incident',
#   'services',
#   'halt',
#   'outside',
#   'shrews',
#   'ambulance',
#   'scene'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['new',
#   'nanotech',
#   'device',
#   'will',
#   'be',
#   'able',
#   'to',
#   'target',
#   'and',
#   'destroy',
#   'blood',
#   'clots'],
#  ['hella', 'crazy', 'fights', 'ambulance', 'couple', 'mosh', 'pits'],
#  ['if',
#   'i',
#   'get',
#   'run',
#   'ambulance',
#   'i',
#   'lucky',
#   'justsaying',
#   'randomthought'],
#  ['news',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'tilnow',
#   'dna'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['tanslash', 'waiting', 'ambulance'],
#  ['fouseytube', 'ok', 'need', 'ambulance', 'hahahah', 'good'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['pakistan', 'air', 'ambulance', 'helicopter', 'crash', 'kills', 'nine'],
#  ['thenissonian',
#   'rejectdcartoons',
#   'nissan',
#   'ok',
#   'need',
#   'medical',
#   'assistance',
#   'call',
#   'ambulance',
#   'need'],
#  ['ny', 'emts', 'petition', 'per', 'hour', 'ems', 'paramedics', 'ambulance'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['ambulance',
#   'sprinter',
#   'automatic',
#   'frontline',
#   'vehicle',
#   'choice',
#   'of',
#   'lez',
#   'compliant',
#   'ebay'],
#  ['kiwikaryn',
#   'check',
#   'whats',
#   'parking',
#   'lot',
#   'he',
#   'said',
#   'last',
#   'year',
#   'ambulance',
#   'st',
#   'johns'],
#  ['dont', 'know', 'way', 'ambulance', 'coming', 'ltlt'],
#  ['reuters',
#   'twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['why', 'ambulance', 'right', 'outside', 'work'],
#  ['this', 'dog', 'thinks', 'hes', 'ambulance'],
#  ['happening',
#   'now',
#   'hatzolah',
#   'ems',
#   'ambulance',
#   'responding',
#   'with',
#   'dual',
#   'sirens'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'worldnews'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash',
#   'worldnews'],
#  ['whats', 'police', 'ambulance', 'number', 'lesotho', 'any', 'body', 'know'],
#  ['aaceorg',
#   'i',
#   'surprised',
#   'still',
#   'standardised',
#   'clinical',
#   'practice',
#   'across',
#   'nhs',
#   'ambulance',
#   'trust'],
#  ['twelve',
#   'feared',
#   'killed',
#   'pakistani',
#   'air',
#   'ambulance',
#   'helicopter',
#   'crash'],
#  ['people', 'try', 'jwalk', 'ambulance', 'passing', 'i', 'hate'],
#  ['the',
#   'episode',
#   'trunks',
#   'annihilated',
#   'freiza',
#   'cleanest',
#   'shit',
#   'ever',
#   'he',
#   'showed',
#   'nigga',
#   'mercy'],
#  ['they',
#   'shall',
#   'be',
#   'annihilated',
#   'and',
#   'all',
#   'of',
#   'their',
#   'petebests',
#   'dessicated',
#   'and',
#   'laid',
#   'bare',
#   'then',
#   'you',
#   'shall',
#   'kneel',
#   'before',
#   'me'],
#  ['uribe', 'annihilated', 'baseball', 'mets'],
#  ['marksmaponyane',
#   'heysundowns',
#   'annihilated',
#   'previous',
#   'meeting',
#   'celticindeed',
#   'improvement'],
#  ['tneazzy',
#   'mizzou',
#   'annihilated',
#   'florida',
#   'past',
#   'seasons',
#   'even',
#   'ended',
#   'muschamps',
#   'career',
#   'cant',
#   'compete',
#   'bama'],
#  ['annihilated', 'abs'],
#  ['be',
#   'annihilated',
#   'status',
#   'education',
#   'mba',
#   'behalf',
#   'easy',
#   'street',
#   'careen',
#   'eovm'],
#  ['luka',
#   'they',
#   'die',
#   'all',
#   'everything',
#   'annihilated',
#   'alois',
#   'trancy'],
#  ['acarewornheart',
#   'have',
#   'good',
#   'un',
#   'fella',
#   'sorry',
#   'i',
#   'wont',
#   'get',
#   'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'via',
#   'viralspell'],
#  ['you', 'must', 'annihilated'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'via',
#   'viralspell'],
#  ['boom', 'your', 'country', 'entirely', 'annihilated', 'britain'],
#  ['amirkingkhan',
#   'would',
#   'annihilated',
#   'might',
#   'well',
#   'thank',
#   'floydmayweather'],
#  ['one',
#   'thing',
#   'suregod',
#   'promised',
#   'israel',
#   'annihilated',
#   'butthe',
#   'horror',
#   'iran',
#   'wnukes'],
#  ['violentfeminazi',
#   'i',
#   'guess',
#   'thats',
#   'ok',
#   'armenians',
#   'since',
#   'weve',
#   'spent',
#   'history',
#   'getting',
#   'annihilated'],
#  ['years',
#   'since',
#   'annihilated',
#   'people',
#   'instantly',
#   'became',
#   'aware',
#   'ability',
#   'annihilate',
#   'whole',
#   'humanity'],
#  ['day',
#   'tryouts',
#   'went',
#   'good',
#   'minus',
#   'fact',
#   'i',
#   'stopped',
#   'quickly',
#   'get',
#   'short',
#   'ball',
#   'annihilated',
#   'toenail',
#   'injury',
#   'even'],
#  ['during',
#   'oryx',
#   'symbol',
#   'arabian',
#   'peninsula',
#   'annihilated',
#   'hunters'],
#  ['to',
#   'luka',
#   'they',
#   'die',
#   'all',
#   'everything',
#   'annihilated',
#   'alois',
#   'trancy'],
#  ['ready', 'get', 'annihilated', 'bucs', 'game'],
#  ['philipduncan',
#   'breakfastone',
#   'people',
#   'annihilated',
#   'last',
#   'nights',
#   'weather',
#   'really',
#   'philip',
#   'thought',
#   'would',
#   'forecast'],
#  ['domain',
#   'sophistication',
#   'annihilated',
#   'closely',
#   'uptotheminute',
#   'feat',
#   'zrnf'],
#  ['stormbeard',
#   'steellord',
#   'i',
#   'seen',
#   'judas',
#   'priest',
#   'rob',
#   'came',
#   'back',
#   'scorpions',
#   'support',
#   'fucking',
#   'annihilated',
#   'place',
#   'astonishing',
#   'gig'],
#  ['officially',
#   'skipping',
#   'hashtag',
#   'its',
#   'getting',
#   'annihilated',
#   'reviews',
#   'bummer'],
#  ['tomcatarts',
#   'thus',
#   'explaining',
#   'annihilated',
#   'but',
#   'case',
#   'survivor',
#   'evolved',
#   'became',
#   'godlike'],
#  ['completely', 'annihilated', 'cech', 'paul', 'keegan', 'time', 'alive'],
#  ['tomcatarts',
#   'annihilated',
#   'legion',
#   'the',
#   'survivors',
#   'imperfect',
#   'hybrid',
#   'project',
#   'quickly',
#   'formed',
#   'new',
#   'secret',
#   'cell'],
#  ['sirbrandonknt',
#   'exactly',
#   'thats',
#   'lesnarcena',
#   'match',
#   'summerslam',
#   'last',
#   'year',
#   'great',
#   'brock',
#   'annihilated',
#   'guy',
#   'whos'],
#  ['cop',
#   'pulls',
#   'drunk',
#   'driver',
#   'safety',
#   'seconds',
#   'car',
#   'hit',
#   'train',
#   'via',
#   'viralspell'],
#  ['annihilated',
#   'in',
#   'damascus',
#   'syrian',
#   'army',
#   'grinds',
#   'and',
#   'his',
#   'gang',
#   'into',
#   'the',
#   'manure',
#   'pile'],
#  ['thatdes',
#   'ok',
#   'wasnt',
#   'completely',
#   'forthright',
#   'may',
#   'also',
#   'food',
#   'coma',
#   'bc',
#   'kebabtahinipickles',
#   'also',
#   'annihilated',
#   'wfries'],
#  ['a',
#   'fun',
#   'filled',
#   'happyhour',
#   'simmons',
#   'bar',
#   'camden',
#   'handsome',
#   'one',
#   'i',
#   'got',
#   'annihilated',
#   'apart',
#   'game'],
#  ['juanny', 'beisbol', 'sr', 'annihilated', 'ball', 'lgm'],
#  ['rvfriedmann',
#   'hell',
#   'fraction',
#   'belief',
#   'total',
#   'annihilation',
#   'destruction',
#   'usa',
#   'lodisilverado',
#   'ritzyjewels'],
#  ['potus',
#   'maybe',
#   'call',
#   'israel',
#   'tell',
#   'sorry',
#   'pres',
#   'sold',
#   'river',
#   'annihilation'],
#  ['evildead', 'annihilation', 'civilization'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['annihilating', 'quarterstaff', 'annihilation'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans'],
#  ['starmade', 'stardate', 'planetary', 'annihilation', 'via', 'youtube'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['kimkardashian',
#   'please',
#   'sign',
#   'share',
#   'petition',
#   'save',
#   'wild',
#   'horses',
#   'arizona'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['theellenshow',
#   'please',
#   'check',
#   'salt',
#   'river',
#   'horses',
#   'help',
#   'stop',
#   'annihilation',
#   'happen',
#   'without',
#   'signatureschange',
#   'org',
#   'thx'],
#  ['are', 'souls', 'punished', 'withåêannihilation'],
#  ['calfreedommom',
#   'mention',
#   'major',
#   'contributor',
#   'annihilation',
#   'israel'],
#  ['willienelson',
#   'we',
#   'need',
#   'help',
#   'horses',
#   'dieplease',
#   'rt',
#   'amp',
#   'sign',
#   'petitiontake',
#   'stand',
#   'amp',
#   'voice'],
#  ['i',
#   'reject',
#   'laws',
#   'misguided',
#   'false',
#   'prophets',
#   'imprison',
#   'nations',
#   'fueling',
#   'self',
#   'annihilation'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['the',
#   'annihilation',
#   'jeb',
#   'christie',
#   'amp',
#   'kasich',
#   'less',
#   'hours',
#   'away',
#   'please',
#   'god',
#   'allow',
#   'least',
#   'one',
#   'full',
#   'day'],
#  ['barbitwins',
#   'we',
#   'need',
#   'helphorses',
#   'die',
#   'please',
#   'rt',
#   'amp',
#   'sign',
#   'petition',
#   'take',
#   'stand',
#   'amp',
#   'voice'],
#  ['whippenz',
#   'we',
#   'need',
#   'help',
#   'horses',
#   'dieplease',
#   'rt',
#   'amp',
#   'sign',
#   'petitiontake',
#   'stand',
#   'amp',
#   'voice'],
#  ['hey',
#   'az',
#   'sign',
#   'petition',
#   'save',
#   'wildhorses',
#   'tantonationalforest',
#   'a',
#   'rollingstones',
#   'singalong',
#   'order'],
#  ['stop', 'annihilation', 'salt', 'river', 'wild', 'horses', 'via', 'change'],
#  ['sonofbaldwin',
#   'hes',
#   'current',
#   'nova',
#   'bookslast',
#   'i',
#   'checkedhe',
#   'tied',
#   'books',
#   'rider',
#   'died',
#   'annihilation'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['please', 'sign', 'amp', 'rt', 'save', 'saltriverwildhorses'],
#  ['thanks',
#   'count',
#   'dante',
#   'do',
#   'join',
#   'us',
#   'by',
#   'following',
#   'the',
#   'annihilation',
#   'zone',
#   'johnny'],
#  ['world',
#   'annihilation',
#   'vs',
#   'self',
#   'transformation',
#   'aliens',
#   'attack',
#   'exterminate',
#   'humans'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['us',
#   'national',
#   'park',
#   'services',
#   'tonto',
#   'national',
#   'forest',
#   'stop',
#   'annihilation',
#   'salt',
#   'river',
#   'wild',
#   'horse',
#   'via',
#   'change'],
#  ['im', 'gon', 'na', 'fight', 'taylor', 'soon', 'i', 'get'],
#  ['ohh',
#   'no',
#   'fukurodani',
#   'didnt',
#   'survive',
#   'the',
#   'apocalypse',
#   'bokuto',
#   'feels',
#   'horrible',
#   'poor',
#   'boy',
#   'ppor',
#   'child'],
#  ['another', 'jocelyn', 'birthday', 'apocalypse'],
#  ['rt',
#   'rt',
#   'stephenscifi',
#   'adaptation',
#   'watch',
#   'charlie',
#   'humans',
#   'apocalypse',
#   'now',
#   'now',
#   'optioned',
#   'film',
#   'sciencefiction'],
#  ['apocalypse', 'please'],
#  ['another',
#   'hour',
#   'its',
#   'august',
#   'heres',
#   'red',
#   'rover',
#   'zombie',
#   'apocalypse',
#   'internetradio'],
#  ['honeybunzgem',
#   'primalkitchen',
#   'i',
#   'feel',
#   'like',
#   'pullup',
#   'one',
#   'stages',
#   'apocalypse'],
#  ['shes',
#   'kinda',
#   'hot',
#   'played',
#   'radio',
#   'today',
#   'whats',
#   'next',
#   'disease',
#   'the',
#   'apocalypse',
#   'started',
#   'everyone',
#   'be',
#   'careful'],
#  ['but', 'apocalypse', 'lol', 'gf'],
#  ['i',
#   'know',
#   'question',
#   'interpretation',
#   'sign',
#   'apocalypse',
#   'i',
#   'called'],
#  ['julie', 'r', 'apocalypse', 'version', 'romeo', 'juliet', 'warmbodies'],
#  ['apocalypse', 'upon', 'us'],
#  ['rt',
#   'fittscott',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more',
#   'mod',
#   'showcase',
#   'popularmmos'],
#  ['and', 'begins', 'day', 'one', 'snow', 'apocalypse'],
#  ['rt',
#   'ourmothermary',
#   'short',
#   'reading',
#   'apocalypse',
#   'in',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain'],
#  ['candylit',
#   'imagine',
#   'sarumi',
#   'zombie',
#   'apocalypse',
#   'fighting',
#   'back',
#   'back',
#   'heart',
#   'heart',
#   'conversations'],
#  ['rt',
#   'i',
#   'liked',
#   'youtube',
#   'video',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more'],
#  ['and', 'thats', 'planet', 'lone', 'audience', 'apocalypse'],
#  ['dad',
#   'bought',
#   'dvd',
#   'looks',
#   'like',
#   'science',
#   'doc',
#   'front',
#   'i',
#   'read',
#   'back',
#   'actually',
#   'impending',
#   'biblical',
#   'apocalypse'],
#  ['alexandrapullin',
#   'it',
#   'indeed',
#   'if',
#   'apocalypse',
#   'comes',
#   'week',
#   'i',
#   'know',
#   'ill'],
#  ['go',
#   'look',
#   'at',
#   'grizzly',
#   'peak',
#   'right',
#   'now',
#   'it',
#   'looks',
#   'like',
#   'beginning',
#   'dystopian',
#   'apocalypse',
#   'movie'],
#  ['my', 'niece', 'asked', 'would', 'scared', 'apocalypse'],
#  ['theres',
#   'storm',
#   'cairo',
#   'latest',
#   'xmen',
#   'apocalypse',
#   'set',
#   'photo',
#   'via',
#   'yahootv'],
#  ['minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more',
#   'mod',
#   'showcase',
#   'popularmmos',
#   'via',
#   'youtube'],
#  ['shot',
#   'through',
#   'the',
#   'heart',
#   'xv',
#   'you',
#   'going',
#   'totally',
#   'give',
#   'love',
#   'bad',
#   'name',
#   'heart',
#   'pierc'],
#  ['rt',
#   'geekapocalypse',
#   'gmt',
#   'hesse',
#   'plays',
#   'dark',
#   'souls',
#   'day',
#   'etcpb'],
#  ['i', 'know', 'go', 'zombies', 'take'],
#  ['the',
#   'latest',
#   'bryansinger',
#   'reveals',
#   'storm',
#   'queen',
#   'apocalypse',
#   'rupaul',
#   'alexshipppp'],
#  ['shadow', 'boxing', 'apocalypse'],
#  ['short',
#   'reading',
#   'apocalypse',
#   'in',
#   'spirit',
#   'angel',
#   'took',
#   'top',
#   'enormous',
#   'high',
#   'mountain'],
#  ['enjoyed',
#   'liveaction',
#   'attack',
#   'titan',
#   'every',
#   'time',
#   'i',
#   'see',
#   'posters',
#   'im',
#   'reminded',
#   'freshly',
#   'clean',
#   'coiffed',
#   'everyone',
#   'apocalypse'],
#  ['i',
#   'liked',
#   'youtube',
#   'video',
#   'minecraft',
#   'night',
#   'lucky',
#   'block',
#   'mod',
#   'bob',
#   'apocalypse',
#   'wither',
#   'amp',
#   'more',
#   'mod',
#   'showcase'],
#  ['pbban',
#   'avysss',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['pbban',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['official',
#   'vid',
#   'doublecups',
#   'gtgt',
#   'gtgt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gtgt',
#   'armageddon'],
#  ['ouvindo', 'peace', 'love', 'amp', 'armageddon'],
#  ['best', 'movie', 'youve', 'ever', 'seen', 'armageddon'],
#  ['bed',
#   'time',
#   'dont',
#   'wake',
#   'unless',
#   'revolution',
#   'armageddon',
#   'start'],
#  ['red', 'faction', 'armageddon', 'microsoft', 'xbox', 'full', 'read', 'ebay'],
#  ['katiekatcubs',
#   'already',
#   'know',
#   'shit',
#   'goes',
#   'world',
#   'series',
#   'armageddon'],
#  ['rt',
#   'love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'rtrrt',
#   'lotz',
#   'apocalypse',
#   'armageddon'],
#  ['im',
#   'gon',
#   'na',
#   'beat',
#   'armageddon',
#   'hsu',
#   'hao',
#   'got',
#   'flawless',
#   'first',
#   'try'],
#  ['enews',
#   'ben',
#   'afflecki',
#   'know',
#   'theres',
#   'wifekids',
#   'girls',
#   'i',
#   'cant',
#   'help',
#   'ive',
#   'loved',
#   'since',
#   'armageddon',
#   'eonlinechat'],
#  ['if',
#   'id',
#   'long',
#   'coat',
#   'hand',
#   'id',
#   'worn',
#   'the',
#   'certainty',
#   'armageddon',
#   'bears',
#   'sense',
#   'occasion'],
#  ['your',
#   'phone',
#   'is',
#   'spying',
#   'on',
#   'you',
#   'hidden',
#   'back',
#   'door',
#   'nsa',
#   'data',
#   'mining',
#   'software',
#   'the',
#   'financial',
#   'armageddon',
#   'blog'],
#  ['pbban',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['rt',
#   'rtrrtcoach',
#   'love',
#   'truelove',
#   'romance',
#   'lith',
#   'voodoo',
#   'seduction',
#   'astrology',
#   'rtrrt',
#   'lotz',
#   'apocalypse',
#   'armageddon'],
#  ['pbban',
#   'fighterdena',
#   'armageddon',
#   'do',
#   'not',
#   'kill',
#   'flags',
#   'only',
#   'fast',
#   'xp',
#   'reason'],
#  ['photo',
#   'sketch',
#   'i',
#   'based',
#   'a',
#   'taste',
#   'armageddon',
#   'episode',
#   'startrek',
#   'tos'],
#  ['armageddon'],
#  ['aberdeenfc',
#   'aberdeenfanpage',
#   'good',
#   'luck',
#   'tomorrow',
#   'night',
#   'get',
#   'coefficient',
#   'points',
#   'plz',
#   'armageddon'],
#  ['armageddon'],
#  ['rohnertparkdps',
#   'youre',
#   'another',
#   'one',
#   'history',
#   'books',
#   'thank',
#   'justice',
#   'department',
#   'and',
#   'way',
#   'i',
#   'havent',
#   'paid',
#   'income',
#   'tax'],
#  ['vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'but',
#   'is',
#   'it',
#   'too',
#   'late',
#   'to',
#   'escape',
#   'armageddon'],
#  ['gods',
#   'kingdom',
#   'heavenly',
#   'govt',
#   'rule',
#   'people',
#   'earth',
#   'armageddon'],
#  ['l',
#   'b',
#   'entertainment',
#   'lot',
#   'brucewillis',
#   'movies',
#   'dvd',
#   'die',
#   'hard',
#   'monkeys',
#   'armageddon',
#   'sixth',
#   'ebay',
#   'auction'],
#  ['talk', 'goof', 'guild', 'saunders', 'come', 'right', 'stage'],
#  ['karnythia',
#   'niece',
#   'gaining',
#   'ability',
#   'stand',
#   'im',
#   'getting',
#   'prepared',
#   'toddler',
#   'apocalypse',
#   'armageddon'],
#  ['check',
#   'preppers',
#   'doomsday',
#   'must',
#   'have',
#   'library',
#   'collection',
#   'on',
#   'cd',
#   'shtf',
#   'preppertalk',
#   'survival',
#   'prepper',
#   'via',
#   'ebay'],
#  ['erker',
#   'again',
#   'eep',
#   'thought',
#   'yesterday',
#   'i',
#   'saw',
#   'hella',
#   'scary',
#   'hail',
#   'armageddon'],
#  ['so',
#   'ahamedis',
#   'think',
#   'messiah',
#   'already',
#   'come',
#   'years',
#   'ago',
#   'where',
#   'armageddon',
#   'where',
#   'dajaal',
#   'where',
#   'gog',
#   'amp',
#   'magog'],
#  ['sadly', 'how', 'windows', 'reveals', 'microsofts', 'ethics', 'armageddon'],
#  ['armageddon', 'averted', 'el', 'patron', 'ultimalucha'],
#  ['samihonkonen',
#   'if',
#   'time',
#   'hours',
#   'latest',
#   'series',
#   'blueprint',
#   'armageddon',
#   'extremely',
#   'impressive'],
#  ['european', 'fitba', 'till', 'christmas', 'armageddon'],
#  ['christians',
#   'united',
#   'israel',
#   'cufi',
#   'jews',
#   'convert',
#   'soon',
#   'die',
#   'armageddon',
#   'us'],
#  ['official',
#   'vid',
#   'gt',
#   'doublecups',
#   'gtgt',
#   'gtgt',
#   'trubgme',
#   'prod',
#   'thisizbwright',
#   'gtgt',
#   'armageddon'],
#  ['tomorrow', 'day', 'start', 'armageddon', 'preseasonworkouts'],
#  ['lee', 'comedy', 'working', 'class', 'tories', 'prepare', 'armageddon'],
#  ['charts',
#   'prove',
#   'financial',
#   'crisis',
#   'part',
#   'has',
#   'begun',
#   'the',
#   'financial',
#   'armageddon',
#   'economic',
#   'collapse',
#   'blog',
#   'tracks',
#   'tren'],
#  ['paul',
#   'craig',
#   'roberts',
#   'vladimir',
#   'putin',
#   'issues',
#   'major',
#   'warning',
#   'but',
#   'is',
#   'it',
#   'too',
#   'late',
#   'to',
#   'escape',
#   'a',
#   'brics',
#   'roberts',
#   'russia'],
#  ['rohnertparkdps',
#   'youre',
#   'stage',
#   'right',
#   'lights',
#   'isnt',
#   'funny',
#   'where',
#   'get',
#   'goofballs',
#   'staff',
#   'pd'],
#  ['official',
#   'vid',
#   'thereal',
#   'gtgtgt',
#   'gtgtgt',
#   'trubgme',
#   'gtgtgt',
#   'armageddon',
#   'comin',
#   'soon'],
#  ['well',
#   'done',
#   'celtic',
#   'fingers',
#   'crossed',
#   'aberdeen',
#   'tomorrow',
#   'night',
#   'armageddon',
#   'eh'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['seconds', 'summer', 'is', 'pick', 'fan', 'army'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['seeing',
#   'army',
#   'whitewalkers',
#   'first',
#   'thing',
#   'slightly',
#   'intrigued',
#   'got',
#   'far'],
#  ['build',
#   'kingdom',
#   'lead',
#   'army',
#   'victory',
#   'start',
#   'g',
#   'friend',
#   'code',
#   'lzktjnox'],
#  ['salvation',
#   'army',
#   'hosts',
#   'rally',
#   'reconnect',
#   'fathers',
#   'children',
#   'the',
#   'salvation',
#   'army',
#   'hosting',
#   'back',
#   'school'],
#  ['vote',
#   'directioners',
#   'vs',
#   'queens',
#   'round',
#   'billboard',
#   'fanarmyfaceoff'],
#  ['but',
#   'build',
#   'army',
#   'dogs',
#   'leader',
#   'lion',
#   'dogs',
#   'fight',
#   'like',
#   'lion'],
#  ['show', 'me', 'hero', 'tv', 'review'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['infantry',
#   'mens',
#   'lume',
#   'dial',
#   'army',
#   'analog',
#   'quartz',
#   'wrist',
#   'watch',
#   'sport',
#   'blue',
#   'nylon',
#   'fabric',
#   'full'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['victorinox', 'swiss', 'army', 'date', 'womens', 'rubber', 'mop', 'watch'],
#  ['rt', 'indiakomuntorjawabdo', 'indian', 'army'],
#  ['seconds', 'summer', 'is', 'pick', 'fan', 'army'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['you',
#   'da',
#   'one',
#   'mtvsummerstar',
#   'videoveranomtv',
#   'mtvhottest',
#   'britney',
#   'spears',
#   'lana',
#   'del',
#   'rey'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['stony',
#   'jackson',
#   'americas',
#   'last',
#   'hope',
#   'leads',
#   'army',
#   'felons',
#   'thus',
#   'army',
#   'rejects',
#   'army',
#   'satan'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['beyonce', 'is', 'pick', 'fan', 'army', 'beyhive'],
#  ['is', 'pick', 'fan', 'army', 'beyhive'],
#  ['potus',
#   'appoints',
#   'brig',
#   'gen',
#   'richard',
#   'g',
#   'kaiser',
#   'member',
#   'mississippi',
#   'river',
#   'commission',
#   'learn',
#   'mrc'],
#  ['ap',
#   'violent',
#   'country',
#   'get',
#   'army',
#   'involved',
#   'help',
#   'control',
#   'killings',
#   'bring',
#   'back',
#   'peace',
#   'poor',
#   'people'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['wwi',
#   'wwii',
#   'japanese',
#   'army',
#   'navy',
#   'military',
#   'japan',
#   'leather',
#   'watch',
#   'war',
#   'mido',
#   'full',
#   'read',
#   'ebay'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['one', 'direction', 'is', 'pick', 'fan', 'army', 'directioners'],
#  ['two',
#   'jewish',
#   'terrorists',
#   'charged',
#   'in',
#   'historicchurch',
#   'arson',
#   'the',
#   'ugly',
#   'truth'],
#  ['spokane',
#   'authorities',
#   'say',
#   'theyre',
#   'struggling',
#   'solve',
#   'arson',
#   'cases',
#   'like',
#   'todays',
#   'hamilton'],
#  ['thousands',
#   'attend',
#   'rally',
#   'organized',
#   'peace',
#   'now',
#   'protesting',
#   'arson',
#   'attack',
#   'took',
#   'life'],
#  ['add', 'familia', 'arson', 'squad'],
#  ['another',
#   'fake',
#   'hate',
#   'crime',
#   'lesbians',
#   'burn',
#   'house',
#   'what',
#   'else',
#   'is',
#   'new'],
#  ['los',
#   'angeles',
#   'times',
#   'arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'newsintweets'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['the', 'sound', 'arson'],
#  ['owner', 'chicagoarea', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['wait', 'what'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['trial', 'date', 'set', 'man', 'charged', 'arson', 'burglary'],
#  ['after',
#   'death',
#   'palestinian',
#   'toddler',
#   'arson',
#   'attack',
#   'israel',
#   'cracks',
#   'jewish'],
#  ['palestinian',
#   'teen',
#   'killed',
#   'amid',
#   'protests',
#   'against',
#   'arson',
#   'attack'],
#  ['kisii',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'failed',
#   'arson',
#   'plot',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'countynews'],
#  ['mariah', 'getting', 'thick', 'shoulders', 'poor', 'girl'],
#  ['mourning',
#   'notices',
#   'stabbing',
#   'arson',
#   'victims',
#   'stir',
#   'israel',
#   'posters',
#   'shira',
#   'banki',
#   'a'],
#  ['relaxinpr',
#   'miprv',
#   'rt',
#   'latimes',
#   'arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california'],
#  ['jewish',
#   'leaders',
#   'prayed',
#   'hospital',
#   'palestinian',
#   'family',
#   'treated',
#   'arson',
#   'via',
#   'huffpostrelig'],
#  ['owner',
#   'chicagoarea',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'via',
#   'theadvocatemag',
#   'lgbt'],
#  ['saynae', 'angel', 'arson'],
#  ['kisii',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'failed',
#   'arson',
#   'plot',
#   'police',
#   'kisii',
#   'hunt',
#   'students',
#   'countynews'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['owner',
#   'chicagoarea',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'via',
#   'theadvocatemag',
#   'lgbt'],
#  ['owner', 'chicagoarea', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['mourning', 'notices', 'stabbing', 'arson', 'victims', 'stir', 'israel'],
#  ['owner', 'chicagoarea', 'gay', 'bar', 'admits', 'arson', 'scheme', 'lgbt'],
#  ['arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california',
#   'via',
#   'latimes'],
#  ['tennessee',
#   'lesbian',
#   'couple',
#   'faked',
#   'hate',
#   'crime',
#   'destroyed',
#   'home',
#   'lesbian'],
#  ['arson',
#   'suspect',
#   'linked',
#   'fires',
#   'caught',
#   'northern',
#   'california',
#   'los',
#   'angeles',
#   'times'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['cloudygoldrush', 'hate', 'white', 'people', 'mo'],
#  ['nowplaying', 'arsonist', 'mc', 'so', 'impressed', 'arsonistmusic'],
#  ['alleged', 'east', 'bay', 'serial', 'arsonist', 'arrested'],
#  ['safyuan',
#   'minor',
#   'citation',
#   'possesion',
#   'decriminalized',
#   'substance',
#   'im',
#   'facing',
#   'time'],
#  ['suspected', 'serial', 'arsonist', 'arrested', 'calif'],
#  ['arson', 'suspect', 'linked', 'fires', 'caught', 'northern', 'california'],
#  ['localarsonist', 'diamorfiend', 'legal', 'system', 'never', 'forgets'],
#  ['casperrmg', 'u', 'dick'],
#  ['bloorossington',
#   'arsonist',
#   'also',
#   'burned',
#   'mattress',
#   'northumberland',
#   'st',
#   'cbcto'],
#  ['wheres', 'my', 'arsonist', 'at'],
#  ['if', 'dont', 'anything', 'nice', 'say', 'come', 'sit'],
#  ['vegetarian',
#   'vegan',
#   'video',
#   'shows',
#   'arsonist',
#   'torching',
#   'popular',
#   'bk',
#   'restaurant',
#   'strictly',
#   'vegetarian',
#   'govegan',
#   'uniteblue'],
#  ['arsonist',
#   'arrested',
#   'setting',
#   'many',
#   'fires',
#   'watch',
#   'headlines',
#   'nightbeat',
#   'veronicadlcruz'],
#  ['video',
#   'captures',
#   'man',
#   'removing',
#   'american',
#   'flag',
#   'from',
#   'long',
#   'beach',
#   'ca',
#   'home',
#   'burning',
#   'it',
#   'arsonist',
#   'sought'],
#  ['trick', 'think', 'nasty', 'things'],
#  ['spotlight',
#   'take',
#   'me',
#   'to',
#   'paradise',
#   'arsonist',
#   'mc',
#   'wniagospel',
#   'arsonistmusic'],
#  ['makes'],
#  ['town', 'salem', 'melted', 'ice', 'cube', 'bc', 'im', 'arsonist', 'd'],
#  ['arsonists',
#   'blamed',
#   'blaze',
#   'plastics',
#   'recycling',
#   'business',
#   'adelaide',
#   'reports'],
#  ['hotboy', 'shit'],
#  ['zodiac',
#   'girl',
#   'feat',
#   'trey',
#   'dupree',
#   'produced',
#   'by',
#   'sparkz',
#   'beatz',
#   'chuck',
#   'da',
#   'arsonist'],
#  ['localarsonist', 'lmfao'],
#  ['alleged', 'east', 'bay', 'serial', 'arsonist', 'arrested', 'sanfrancisco'],
#  ['doofus', 'diamorfiend', 'im', 'jokin', 'still', 'cant', 'moves'],
#  ['localarsonist', 'i', 'guess', 'u', 'say', 'shit', 'i', 'thinking'],
#  ['arsonist',
#   'sets',
#   'nyc',
#   'vegetarian',
#   'restaurant',
#   'fire',
#   'police',
#   'newyork'],
#  ['i',
#   'liked',
#   'youtube',
#   'video',
#   'slimebeast',
#   'town',
#   'salem',
#   'how',
#   'win',
#   'the',
#   'arsonist'],
#  ['casperrmg', 'bestcomedyvine', 'whats', 'cracking', 'cuz'],
#  ['smoke',
#   'good',
#   'fuck',
#   'eat',
#   'drink',
#   'drive',
#   'nice',
#   'car',
#   'wear',
#   'green',
#   'mink'],
#  ['kill', 'got', 'court', 'day', 'earl'],
#  ['localarsonist', 'lmao', 'real', 'live', 'go'],
#  ['owner',
#   'chicagoarea',
#   'gay',
#   'bar',
#   'admits',
#   'arson',
#   'scheme',
#   'frank',
#   'elliott',
#   'pleaded',
#   'guilty',
#   'hiring',
#   'arsonist'],
#  ['trusting',
#   'iran',
#   'stop',
#   'terrorism',
#   'like',
#   'inviting',
#   'arsonist',
#   'join',
#   'fire',
#   'brigade',
#   'telegraph'],
#  ['big',
#   'top',
#   'burning',
#   'the',
#   'true',
#   'story',
#   'of',
#   'an',
#   'arsonist',
#   'a',
#   'missing',
#   'girl'],
#  ['stay',
#   'vigilent',
#   'civil',
#   'liberties',
#   'constant',
#   'attack',
#   'nativehuman',
#   'myreligion'],
#  ['credit', 'pfannebeckers', 'inspiring', 'rediscover', 'fantabulous', 'tbt'],
#  ['nashville',
#   'theater',
#   'attack',
#   'will',
#   'gun',
#   'grabbers',
#   'now',
#   'demand'],
#  ['breaking', 'terror', 'attack', 'on', 'police', 'post', 'udhampur'],
#  ['demi',
#   'stans',
#   'really',
#   'think',
#   'heart',
#   'attack',
#   'sold',
#   'million',
#   'copies'],
#  ['scares',
#   'theres',
#   'new',
#   'versions',
#   'nuclear',
#   'attack',
#   'warnings',
#   'like',
#   'knowing',
#   'governments',
#   'still',
#   'prepare'],
#  ['isil',
#   'claims',
#   'suicide',
#   'bombing',
#   'saudi',
#   'mosque',
#   'killed',
#   'least'],
#  ['dattomm', 'funniest', 'part', 'twitter', 'feminists', 'try', 'attack'],
#  ['horrific', 'attack', 'wife', 'muslim', 'italy', 'liveleak', 'news'],
#  ['blasts',
#   'accused',
#   'yeda',
#   'yakub',
#   'dies',
#   'karachi',
#   'heart',
#   'attack',
#   'mumbai'],
#  ['etribune',
#   'us',
#   'drone',
#   'attack',
#   'kills',
#   'militants',
#   'north',
#   'waziristan',
#   'acebreakingnews'],
#  ['suspect', 'latest', 'theater', 'attack', 'psychological', 'issues'],
#  ['militants',
#   'attack',
#   'police',
#   'post',
#   'udhampur',
#   'spos',
#   'injured',
#   'livemint',
#   'allthenews'],
#  ['breaking',
#   'obama',
#   'officials',
#   'gave',
#   'muslim',
#   'terrorist',
#   'weapon',
#   'used',
#   'texas',
#   'attack'],
#  ['delhi',
#   'government',
#   'provide',
#   'free',
#   'treatment',
#   'acid',
#   'attack',
#   'victims',
#   'private',
#   'hospitals'],
# ...
#   'receive',
#   'blood',
#   'well'],
#  ['doing',
#   'dialyses',
#   'grandpa',
#   'oh',
#   'lord',
#   'blood',
#   'makes',
#   'light',
#   'headed'],
#  ['setzorah',
#   'dad',
#   'dont',
#   'claim',
#   'mean',
#   'right',
#   'look',
#   'eyes',
#   'blood',
#   'xbox',
#   'smh'],
#  ['omron',
#   'automatic',
#   'blood',
#   'pressure',
#   'monitor',
#   'standard',
#   'and',
#   'large',
#   'bp',
#   'cuffs'],
#  ['my', 'blood', 'pressure', 'roof', 'i', 'dont', 'need', 'extra', 'shit'],
#  ['chamberedblood', 'yeah', 'speakingfromexperience'],
#  ['cant',
#   'believe',
#   'people',
#   'mid',
#   'dont',
#   'high',
#   'blood',
#   'pressure',
#   'life',
#   'stressful',
#   'decisionsondecisions'],
#  ['guys', 'i', 'imouto', 'who', 'isnt', 'actually', 'related', 'me', 'blood'],
#  ['bruh',
#   'white',
#   'people',
#   'buy',
#   'ugliest',
#   'shoes',
#   'super',
#   'tight',
#   'blood',
#   'going',
#   'feet'],
#  ['another',
#   'day',
#   'another',
#   'excellent',
#   'dangerousbeans',
#   'porridge',
#   'seriously',
#   'people',
#   'blood',
#   'orange',
#   'porridge',
#   'phenomenal'],
#  ['happy', 'birthday', 'young', 'blood'],
#  ['if', 'wasnt', 'blood'],
#  ['no', 'kinda', 'shii', 'nasty', 'blood', 'no', 'pun', 'intended'],
#  ['aint', 'hoe', 'blood'],
#  ['today',
#   'hastle',
#   'getting',
#   'drug',
#   'tested',
#   'blood',
#   'drown',
#   'tb',
#   'shot',
#   'document',
#   'filling'],
#  ['man',
#   'somebody',
#   'got',
#   'ta',
#   'stop',
#   'sbee',
#   'dude',
#   'fuckin',
#   'funny',
#   'blood'],
#  ['where', 'winds', 'take', 'gypsy', 'blood', 'time'],
#  ['loboparanoico', 'mad', 'men'],
#  ['private', 'thirsty', 'nightsad', 'blood', 'rockn', 'roll'],
#  ['rolandonabeats',
#   'ellie',
#   'goulding',
#   'my',
#   'blood',
#   'acesse',
#   'nosso',
#   'site',
#   'para',
#   'ouvir'],
#  ['olrules',
#   'welcome',
#   'read',
#   'free',
#   'chapter',
#   'new',
#   'book',
#   'encounters',
#   'with',
#   'jesus',
#   'its',
#   'full',
#   'hope'],
#  ['anthxvy', 'runs', 'blood'],
#  ['sethalphaeus',
#   'personal',
#   'favorites',
#   'include',
#   'paramore',
#   'muse',
#   'green',
#   'day',
#   'royal',
#   'blood'],
#  ['shed',
#   'innocent',
#   'blood',
#   'sons',
#   'daughters',
#   'land',
#   'polluted',
#   'psalms',
#   'help',
#   'stop',
#   'sin',
#   'abortion'],
#  ['se', 'pone', 'cantar', 'crying', 'lightning'],
#  ['wasnt',
#   'big',
#   'stab',
#   'deep',
#   'stab',
#   'theres',
#   'like',
#   'blood',
#   'everwhe'],
#  ['add',
#   'items',
#   'everyday',
#   'eating',
#   'habits',
#   'please',
#   'research',
#   'take'],
#  ['looooooooooool', 'bloody', 'hell'],
#  ['infected', 'bloody', 'ear', 'piercings', 'always', 'fun'],
#  ['aggressif', 'bloody', 'aggressive'],
#  ['i',
#   'entered',
#   'win',
#   'entire',
#   'set',
#   'butterlondon',
#   'lip',
#   'crayons',
#   'via',
#   'go',
#   'enter',
#   'bbloggers'],
#  ['slsandpet',
#   'hey',
#   'sally',
#   'sorry',
#   'emailed',
#   'been',
#   'awol',
#   'bloody',
#   'work',
#   'argh',
#   'resigninshame'],
#  ['im', 'listening', 'bloody', 'jay'],
#  ['lauradeholanda',
#   'i',
#   'forrest',
#   'version',
#   'thats',
#   'bloody',
#   'awful',
#   'well',
#   'xxx'],
#  ['a', 'nightmare', 'on', 'elm', 'street', 'is', 'getting', 'remade', 'again'],
#  ['i',
#   'cant',
#   'bloody',
#   'wait',
#   'sony',
#   'sets',
#   'date',
#   'for',
#   'stephen',
#   'dark',
#   'stephenking',
#   'thedarktower',
#   'bdisgusting'],
#  ['got', 'ta', 'try', 'let', 'go', 'many', 'bloody', 'things', 'smh'],
#  ['tradcatknight',
#   'russia',
#   'may',
#   'played',
#   'reason',
#   'link',
#   'bs',
#   'okanowa',
#   'bloody',
#   'mainline',
#   'invasion',
#   'looked',
#   'like',
#   'bloody'],
#  ['bloody', 'insomnia', 'grrrr', 'insomnia'],
#  ['zhenghxn',
#   'tried',
#   'eyes',
#   'akame',
#   'ga',
#   'kill',
#   'tokyo',
#   'ghoul',
#   'damn',
#   'bloody',
#   'dont',
#   'dare',
#   'watch'],
#  ['fantosex',
#   'now',
#   'suck',
#   'thats',
#   'youre',
#   'bloody',
#   'getting',
#   'means',
#   'amends'],
#  ['you',
#   'call',
#   'weekends',
#   'i',
#   'call',
#   'bloody',
#   'mary',
#   'times',
#   'this',
#   'summers',
#   'full',
#   'my'],
#  ['bloody',
#   'hell',
#   'day',
#   'i',
#   'havent',
#   'even',
#   'really',
#   'done',
#   'anything',
#   'just',
#   'tired',
#   'of',
#   'everything',
#   'thought',
#   'vaca',
#   'would',
#   'help',
#   'much'],
#  ['damn', 'bloody', 'hot'],
#  ['mrtophypup', 'bloody', 'sexy', 'drools'],
#  ['you',
#   'know',
#   'say',
#   'side',
#   'effects',
#   'low',
#   'amp',
#   'really',
#   'fast',
#   'son',
#   'product',
#   'acne',
#   'cream',
#   'why',
#   'side',
#   'effects',
#   'bloody',
#   'diarrhea'],
#  ['ronda',
#   'rousey',
#   'would',
#   'close',
#   'making',
#   'floyd',
#   'mayweathers',
#   'money',
#   'fights',
#   'bloody',
#   'elbow',
#   'boxing'],
#  ['im',
#   'awful',
#   'painting',
#   'i',
#   'agree',
#   'landscape',
#   'bloody',
#   'oils',
#   'paints'],
#  ['all',
#   'i',
#   'need',
#   'life',
#   'sin',
#   'is',
#   'girlfriend',
#   'down',
#   'ride',
#   'till',
#   'bloody',
#   'end',
#   'just',
#   'girlfriend'],
#  ['itsmegss', 'i', 'think', 'well', 'bloody', 'barking'],
#  ['eh',
#   'hello',
#   'cover',
#   'bloody',
#   'thighs',
#   'bloody',
#   'cleav',
#   'eh',
#   'hello',
#   'since',
#   'expose',
#   'cleavage'],
#  ['johnjcampbell', 'mega', 'bloody', 'marvellous'],
#  ['bloody', 'mary', 'sink', 'beet', 'juice'],
#  ['melrises',
#   'wwwbigbaldhead',
#   'jessienojoke',
#   'monty',
#   'python',
#   'date',
#   'bloody',
#   'far',
#   'wants',
#   'go'],
#  ['meet', 'bloody'],
#  ['friday', 'supposed', 'happy', 'day', 'bloody', 'friday', 'hah', 'zzzz'],
#  ['chxrmingprince',
#   'jonesluna',
#   'i',
#   'bloody',
#   'hope',
#   'said',
#   'folding',
#   'arms',
#   'sitting',
#   'back',
#   'chair'],
#  ['wait',
#   'tell',
#   'college',
#   'friend',
#   'reafs',
#   'bloody',
#   'mary',
#   'drama',
#   'cd'],
#  ['i',
#   'came',
#   'kill',
#   'indiansfor',
#   'fun',
#   'video',
#   'smirking',
#   'remorseless',
#   'pakistani',
#   'killer',
#   'shows',
#   'boasting'],
#  ['ive',
#   'watched',
#   'episode',
#   'bloody',
#   'monday',
#   'bloodymonday',
#   'tvshowtime'],
#  ['marlon',
#   'williams',
#   'gt',
#   'elvis',
#   'presley',
#   'gt',
#   'marlon',
#   'williams',
#   'gt',
#   'steel',
#   'panther',
#   'shuffle',
#   'mode',
#   'like',
#   'bloody',
#   'legend'],
#  ['black',
#   'friday',
#   'turns',
#   'bloody',
#   'would',
#   'rather',
#   'shopping',
#   'mystery'],
#  ['ezralevant',
#   'someone',
#   'told',
#   'soccer',
#   'moms',
#   'getting',
#   'pic',
#   'blown',
#   'put',
#   'daughters',
#   'bedroom',
#   'walls',
#   'not'],
#  ['papcrdoll',
#   'i',
#   'mentions',
#   'get',
#   'blown',
#   'my',
#   'choice',
#   'i',
#   'deactivate',
#   'leave',
#   'good',
#   'respect',
#   'my',
#   'choices'],
#  ['manutd',
#   'emilymcfcheslop',
#   'wow',
#   'wow',
#   'if',
#   'club',
#   'blown',
#   'money',
#   'fucked',
#   'player',
#   'like',
#   'theyd',
#   'pilloried'],
#  ['damn', 'greinke', 'got', 'blown', 'first', 'inning'],
#  ['woke', 'blown', 'lol'],
#  ['aunt', 'marge', 'youre', 'blown', 'eheks'],
#  ['troylercraft',
#   'yeah',
#   'its',
#   'not',
#   'worth',
#   'it',
#   'bc',
#   'he',
#   'already',
#   'has',
#   'so',
#   'many',
#   'spammers',
#   'amp',
#   'his',
#   'twitter',
#   'is',
#   'probably',
#   'blown',
#   'up',
#   'every',
#   'second'],
#  ['white',
#   'family',
#   'supposedly',
#   'representing',
#   'americas',
#   'great',
#   'values',
#   'gets',
#   'blown',
#   'horrible',
#   'cgi',
#   'nuclear',
#   'strike',
#   'lmfaoooo'],
#  ['man', 'hasnt', 'machinegunkelly', 'blown', 'hes', 'still', 'underground'],
#  ['and', 'mentions', 'blown', 'wtf'],
#  ['on',
#   'thisdayinhistory',
#   'confederate',
#   'ship',
#   'blown',
#   'crew',
#   'read',
#   'more',
#   'via',
#   'history'],
#  ['that',
#   'moment',
#   'ur',
#   'win',
#   'mini',
#   'uhc',
#   'get',
#   'blown',
#   'creeper',
#   'get',
#   'kicked',
#   'flying',
#   'so',
#   'salty',
#   'rn'],
#  ['libraryeliza',
#   'get',
#   'bump',
#   'approval',
#   'probably',
#   'hes',
#   'blown',
#   'musicadvisory'],
#  ['if',
#   'truckload',
#   'soldiers',
#   'blown',
#   'nobody',
#   'panics',
#   'one',
#   'little',
#   'lion',
#   'dies',
#   'everyone',
#   'loses',
#   'mind'],
#  ['hey',
#   'look',
#   'kashs',
#   'foundation',
#   'live',
#   'today',
#   'got',
#   'blown',
#   'people',
#   'magazines',
#   'website',
#   'todd',
#   'blake'],
#  ['got',
#   'last',
#   'month',
#   'i',
#   'went',
#   'ee',
#   'shop',
#   'glad',
#   'hasnt',
#   'blown',
#   'yet'],
#  ['first', 'time', 'tweet', 'blown', 'almost', 'half', 'day', 'later', 're'],
#  ['blown', 'away', 'extension', 'nothing', 'seen', 'many', 'options', 'one'],
#  ['theboyofmasks',
#   'thanks',
#   'letting',
#   'stay',
#   'since',
#   'manor',
#   'blown',
#   'anyways',
#   'buddy'],
#  ['loner',
#   'diaries',
#   'the',
#   'patterns',
#   'sand',
#   'may',
#   'blown',
#   'away',
#   'the',
#   'photos',
#   'twos',
#   'all',
#   'choked',
#   'flames'],
#  ['even',
#   'though',
#   'bsg',
#   'sufficiently',
#   'hyped',
#   'years',
#   'i',
#   'somehow',
#   'delayed',
#   'watching',
#   'i',
#   'utterly',
#   'utterly',
#   'blown',
#   'away'],
#  ['vanessas',
#   'game',
#   'officially',
#   'blown',
#   'ladies',
#   'and',
#   'gentlementhe',
#   'real',
#   'show',
#   'begin'],
#  ['guaranteed',
#   'bitten',
#   'mutant',
#   'mosquito',
#   'ankle',
#   'blown',
#   'little',
#   'cunts'],
#  ['things',
#   'can',
#   'pick',
#   'tozlet',
#   'seat',
#   'butt',
#   'leprosy',
#   'fullblown',
#   'jerkface',
#   'syndrome',
#   'lateral',
#   'lisp',
#   'amp',
#   'toilet',
#   'rickets'],
#  ['kalinandmyles',
#   'kalinwhite',
#   'ig',
#   'blown',
#   'hackers',
#   'i',
#   'need',
#   'stop',
#   'givebackkalinwhiteaccount'],
#  ['lukewinkie',
#   'whoever',
#   'directing',
#   'videos',
#   'needs',
#   'grab',
#   'nicki',
#   'minaj',
#   'someone',
#   'us',
#   'recognition',
#   'minds',
#   'blown'],
#  ['princessduck',
#   'last',
#   'week',
#   'wanted',
#   'sense',
#   'get',
#   'blown',
#   'far',
#   'good',
#   'james',
#   'could',
#   'win',
#   'hes',
#   'huge',
#   'target',
#   'gone',
#   'soon'],
#  ['orbette', 'like', 'blown', 'up', 'amirite'],
#  ['my', 'blown', 'kennel', 'bloody', 'yorkshire', 'terrorist'],
#  ['turn', 'get', 'blown'],
#  ['hopefulbatgirl',
#   'went',
#   'i',
#   'beaten',
#   'blown',
#   'then',
#   'next',
#   'thing',
#   'i',
#   'know',
#   'ra',
#   'al',
#   'ghul',
#   'brought',
#   'back',
#   'life',
#   'i',
#   'escaped'],
#  ['thebriankrause',
#   'leos',
#   'ass',
#   'got',
#   'metaphorically',
#   'blown',
#   'piperwearsthepants',
#   'charmed'],
#  ['anarchicteapot',
#   'boironusa',
#   'glononium',
#   'also',
#   'helps',
#   'blown',
#   'bashing',
#   'bottle',
#   'nitroglycerin',
#   'book'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['if',
#   'son',
#   'daughter',
#   'would',
#   'like',
#   'see',
#   'going',
#   'war',
#   'iran',
#   'come',
#   'back',
#   'body',
#   'bag',
#   'let',
#   'republicans',
#   'know'],
#  ['questergirl',
#   'ditto',
#   'way',
#   'feel',
#   'drank',
#   'vodka',
#   'ice',
#   'would',
#   'body',
#   'bag'],
#  ['handbags',
#   'genuine',
#   'mulberry',
#   'antony',
#   'cross',
#   'body',
#   'messenger',
#   'bag',
#   'dark',
#   'oak',
#   'soft',
#   'buffalo',
#   'leather',
#   'date',
#   'w'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['louis',
#   'vuitton',
#   'cultsierre',
#   'monogram',
#   'shoulder',
#   'bag',
#   'cross',
#   'body',
#   'bag'],
#  ['check',
#   'ameribag',
#   'healthy',
#   'back',
#   'bag',
#   'shoulder',
#   'cross',
#   'body',
#   'backpack',
#   'khaki',
#   'tan',
#   'beige',
#   'nylon',
#   'ebay'],
#  ['photo',
#   'bath',
#   'amp',
#   'body',
#   'works',
#   'cosmetic',
#   'bag',
#   'periwinkle',
#   'blue',
#   'copper',
#   'piping',
#   'along',
#   'top',
#   'four',
#   'corners'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'women',
#   'cross',
#   'body',
#   'bag',
#   'faux',
#   'leather',
#   'fashion',
#   'purse',
#   'full'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'a',
#   'word',
#   'skirt',
#   'blue'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'rt'],
#  ['trjdavis',
#   'bruh',
#   'wan',
#   'na',
#   'fight',
#   'im',
#   'meet',
#   'cage',
#   'bro',
#   'better',
#   'find',
#   'youre',
#   'dealing',
#   'end',
#   'body',
#   'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full'],
#  ['auth',
#   'louis',
#   'vuitton',
#   'brown',
#   'saumur',
#   'cross',
#   'body',
#   'shoulder',
#   'bag',
#   'monogram',
#   'full'],
#  ['check',
#   'vintage',
#   'longaberger',
#   'floral',
#   'fabric',
#   'shoulder',
#   'cross',
#   'body',
#   'bag',
#   'brown',
#   'leather',
#   'strap',
#   'ebay'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['new',
#   'summer',
#   'long',
#   'thin',
#   'body',
#   'bag',
#   'hip',
#   'a',
#   'word',
#   'skirt',
#   'blue'],
#  ['ìü',
#   'new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'rt'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['new',
#   'women',
#   'handbag',
#   'faux',
#   'leather',
#   'ladies',
#   'shoulder',
#   'tote',
#   'cross',
#   'body',
#   'bag',
#   'large',
#   'satchel',
#   'full'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['one', 'day', 'heart', 'gone', 'get', 'zipped', 'body', 'bag'],
#  ['handbag',
#   'fashion',
#   'style',
#   'authentic',
#   'louis',
#   'vuitton',
#   'pochette',
#   'bosphore',
#   'shoulder',
#   'cross',
#   'body'],
#  ['å',
#   'new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['handbag',
#   'fashion',
#   'style',
#   'vintage',
#   'coach',
#   'purse',
#   'camera',
#   'bag',
#   'cross',
#   'body',
#   'bids'],
#  ['genuine',
#   'leather',
#   'man',
#   'bag',
#   'messenger',
#   'fit',
#   'ipad',
#   'mini',
#   'tablet',
#   'case',
#   'cross',
#   'body',
#   'air',
#   'jp',
#   'full'],
#  ['louis',
#   'vuitton',
#   'monogram',
#   'sophie',
#   'limited',
#   'edition',
#   'clutch',
#   'cross',
#   'body',
#   'bag',
#   'full',
#   'read',
#   'ebay'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens'],
#  ['nuu', 'fam', 'fwt', 'im', 'leave', 'you', 'in', 'body', 'bag'],
#  ['new',
#   'ladies',
#   'shoulder',
#   'tote',
#   'handbag',
#   'faux',
#   'leather',
#   'hobo',
#   'purse',
#   'cross',
#   'body',
#   'bag',
#   'womens',
#   'full'],
#  ['deliciousvomit',
#   'no',
#   'im',
#   'im',
#   'saying',
#   'theyre',
#   'lucky',
#   'go',
#   'home',
#   'families',
#   'put',
#   'body',
#   'bag'],
#  ['mattbez',
#   'oh',
#   'im',
#   'bagging',
#   'her',
#   'body',
#   'bangin',
#   'im',
#   'saying',
#   'shes',
#   'going',
#   'get',
#   'rose'],
#  ['ohmyloz', 'rondarousey', 'bagging', 'body', 'shes', 'smoking', 'hot'],
#  ['drake', 'really', 'body', 'bagging', 'meek'],
#  ['fuckyeahcarey',
#   'bornverified',
#   'drake',
#   'killing',
#   'dude',
#   'tea',
#   'bagging',
#   'dead',
#   'body',
#   'point'],
#  ['meekmill',
#   'wreck',
#   'league',
#   'ball',
#   'drake',
#   'olympic',
#   'level',
#   'body',
#   'bagging',
#   'like',
#   'career',
#   'nothing',
#   'trollingtilmeekdiss'],
#  ['idgaf',
#   'tough',
#   'canada',
#   'north',
#   'philly',
#   'meek',
#   'acting',
#   'like',
#   'bitch',
#   'amp',
#   'drake',
#   'body',
#   'bagging',
#   'ass',
#   'tracks'],
#  ['yankees', 'body', 'bagging', 'mfs'],
#  ['broseidonrex',
#   'dapurplesharpie',
#   'i',
#   'skimmed',
#   'twitter',
#   'missed',
#   'body',
#   'bagging'],
#  ['g', 'body', 'bagging', 'lyrically'],
#  ['bomairinge', 'elutranscendent', 'straight', 'body', 'bagging'],
#  ['body', 'bagging', 'bitches'],
#  ['no',
#   'better',
#   'feeling',
#   'seeing',
#   'stage',
#   'day',
#   'ones',
#   'year',
#   'friendships',
#   'still',
#   'body',
#   'bagging',
#   'mics',
#   'together'],
#  ['mopheme',
#   'bigstar',
#   'johnson',
#   'problem',
#   'game',
#   'body',
#   'bagging',
#   'niggas',
#   'vuzuhustle'],
#  ['i', 'body', 'bagging', 'post', 'score'],
#  ['editaxohaze',
#   'let',
#   'bagging',
#   'bodys',
#   'begin',
#   'lol',
#   'i',
#   'aint',
#   'cuffed',
#   'yet',
#   'shouldnt',
#   'bad'],
#  ...]

# %%
embedding_dict={}
with open(r'C:\Users\MOMOZZING\WorkSpace\glove.6B\glove.6B.100d.txt','r', encoding = "utf-8") as f:
    for line in f:
        values=line.split()
        word=values[0]
        vectors=np.asarray(values[1:],'float32')
        embedding_dict[word]=vectors
f.close()

# %%
MAX_LEN=50
tokenizer_obj=Tokenizer()
tokenizer_obj.fit_on_texts(corpus)
sequences=tokenizer_obj.texts_to_sequences(corpus)

all_df_pad=pad_sequences(sequences,maxlen=MAX_LEN,truncating='post',padding='post')

# %%
word_index=tokenizer_obj.word_index
print('Number of unique words:',len(word_index))
# Out:
# Number of unique words: 20342

# %%
num_words=len(word_index)+1
embedding_matrix=np.zeros((num_words,100))

for word,i in tqdm(word_index.items()):
    if i > num_words:
        continue
    
    emb_vec=embedding_dict.get(word)
    if emb_vec is not None:
        embedding_matrix[i]=emb_vec
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 20342/20342 [00:00<00:00, 657226.85it/s]

# %%
model=Sequential()

embedding=Embedding(num_words,100,embeddings_initializer=Constant(embedding_matrix),
                   input_length=MAX_LEN,trainable=False)

model.add(embedding)
model.add(SpatialDropout1D(0.2))
model.add(LSTM(64, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))


optimzer=Adam(learning_rate=1e-5)

model.compile(loss='binary_crossentropy',optimizer=optimzer,metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 50, 100)           2034300
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 50, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                42240
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,076,605
# Trainable params: 42,305
# Non-trainable params: 2,034,300
# _________________________________________________________________

# %%
train=all_df_pad[:df_train.shape[0]]
test=all_df_pad[df_train.shape[0]:]

# %%
X_train,X_test,y_train,y_test=train_test_split(train,df_train['target'].values,test_size=0.15)
print('Shape of train',X_train.shape)
print("Shape of Validation ",X_test.shape)
# Out:
# Shape of train (6471, 50)
# Shape of Validation  (1142, 50)

# %%
history=model.fit(X_train,y_train,batch_size=4,epochs=15,validation_data=(X_test,y_test),verbose=2)
# Out:
# Train on 6471 samples, validate on 1142 samples
# Epoch 1/15
#  - 26s - loss: 0.6909 - accuracy: 0.5696 - val_loss: 0.6885 - val_accuracy: 0.5648
# Epoch 2/15
#  - 24s - loss: 0.6783 - accuracy: 0.5713 - val_loss: 0.6570 - val_accuracy: 0.5648
# Epoch 3/15
#  - 23s - loss: 0.6363 - accuracy: 0.6432 - val_loss: 0.5682 - val_accuracy: 0.7662
# Epoch 4/15
#  - 23s - loss: 0.5768 - accuracy: 0.7407 - val_loss: 0.5141 - val_accuracy: 0.7828
# Epoch 5/15
#  - 20s - loss: 0.5636 - accuracy: 0.7413 - val_loss: 0.5017 - val_accuracy: 0.7846
# Epoch 6/15
#  - 20s - loss: 0.5540 - accuracy: 0.7463 - val_loss: 0.4913 - val_accuracy: 0.7837
# Epoch 7/15
#  - 20s - loss: 0.5550 - accuracy: 0.7481 - val_loss: 0.4857 - val_accuracy: 0.7872
# Epoch 8/15
#  - 20s - loss: 0.5499 - accuracy: 0.7481 - val_loss: 0.4842 - val_accuracy: 0.7907
# Epoch 9/15
#  - 20s - loss: 0.5516 - accuracy: 0.7498 - val_loss: 0.4816 - val_accuracy: 0.7933
# Epoch 10/15
#  - 20s - loss: 0.5329 - accuracy: 0.7605 - val_loss: 0.4759 - val_accuracy: 0.7942
# Epoch 11/15
#  - 20s - loss: 0.5405 - accuracy: 0.7589 - val_loss: 0.4750 - val_accuracy: 0.7916
# Epoch 12/15
#  - 26s - loss: 0.5412 - accuracy: 0.7537 - val_loss: 0.4753 - val_accuracy: 0.7855
# Epoch 13/15
#  - 24s - loss: 0.5333 - accuracy: 0.7611 - val_loss: 0.4725 - val_accuracy: 0.7916
# Epoch 14/15
#  - 21s - loss: 0.5351 - accuracy: 0.7589 - val_loss: 0.4713 - val_accuracy: 0.7942
# Epoch 15/15
#  - 21s - loss: 0.5277 - accuracy: 0.7690 - val_loss: 0.4695 - val_accuracy: 0.7933

# %% [markdown]
# https://www.kaggle.com/shahules/basic-eda-cleaning-and-glove

# %%
sample_sub=pd.read_csv(r'C:\Users\MOMOZZING\WorkSpace\kaggle\Real_or_Not\sample_submission.csv')

# %%
y_pre=model.predict(test)

# %%
y_pre=np.round(y_pre).astype(int).reshape(3263 )

# %%
sub=pd.DataFrame({'id':sample_sub['id'].values.tolist(),'target':y_pre})

# %%
sub.to_csv('REAL_OR_NOT_Glove.csv',index=False)

# %%
sub.head()
# Out:
#    id  target
# 0   0       1
# 1   2       1
# 2   3       1
# 3   9       1
# 4  11       1
